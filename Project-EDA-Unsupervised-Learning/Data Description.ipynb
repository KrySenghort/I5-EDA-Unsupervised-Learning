# %% [markdown]
# The dataset contains multiple columns representing economic, social, demographic, and environmental indicators. Below is an explanation of each column based on the provided information:
#
# ### **Economic Indicators**
# 1. **Country** (`object`): The name of the country or region.
# 2. **Year** (`int64`): The year for which the data is recorded.
# 3. **GDP (current US$)** (`float64`): The gross domestic product in current U.S. dollars, indicating the economic size of a country.
# 4. **GDP growth (annual %)** (`float64`): The annual growth rate of GDP, reflecting economic performance.
# 5. **GDP per capita (current US$)** (`float64`): The GDP divided by the total population, indicating average economic output per person.
#
# ### **Labor Market Indicators**
# 6. **Unemployment, total (% of total labor force)** (`float64`): The percentage of the total labor force that is unemployed.
# 7. **Literacy rate, adult total (% of people ages 15 and above)** (`object`): The percentage of adults who can read and write.
#
# ### **Inflation & Trade**
# 8. **Inflation, consumer prices (annual %)** (`float64`): The annual percentage change in consumer prices.
# 9. **Foreign direct investment, net inflows (% of GDP)** (`float64`): The value of foreign direct investment relative to GDP.
# 10. **Trade (% of GDP)** (`float64`): The sum of exports and imports as a percentage of GDP.
#
# ### **Income & Inequality**
# 11. **Gini index** (`float64`): A measure of income inequality, ranging from 0 (perfect equality) to 100 (maximum inequality).
# 12. **Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)** (`object`): The percentage of people living on less than $2.15 per day at 2017 purchasing power parity (PPP).
#
# ### **Demographics**
# 13. **Population, total** (`int64`): The total population of the country.
# 14. **Population growth (annual %)** (`float64`): The annual growth rate of the population.
# 15. **Urban population (% of total population)** (`float64`): The percentage of the population living in urban areas.
# 16. **Life expectancy at birth, total (years)** (`object`): The average number of years a newborn is expected to live.
# 17. **Mortality rate, infant (per 1,000 live births)** (`object`): The number of infant deaths per 1,000 live births.
#
# ### **Health & Education**
# 18. **School enrollment, primary (% gross)** (`object`): The gross enrollment ratio in primary education.
# 19. **Access to electricity (% of population)** (`object`): The percentage of the population with access to electricity.
# 20. **People using at least basic drinking water services (% of population)** (`object`): The percentage of the population with access to basic drinking water services.
# 21. **People using at least basic sanitation services (% of population)** (`object`): The percentage of the population with access to basic sanitation services.
#
# ### **Environment & Energy**
# 22. **Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)** (`object`): CO2 emissions per capita, excluding land use, land-use change, and forestry (LULUCF).
# 23. **PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)** (`object`): The average annual exposure to PM2.5 air pollution.
# 24. **Renewable energy consumption (% of total final energy consumption)** (`object`): The percentage of energy consumption derived from renewable sources.
# 25. **Forest area (% of land area)** (`object`): The percentage of land area covered by forests.
#
# ### **Governance**
# 26. **Control of Corruption: Percentile Rank** (`object`): A measure of perceived corruption in public power.
# 27. **Political Stability and Absence of Violence/Terrorism: Estimate** (`object`): An estimate of political stability and absence of violence/terrorism.
# 28. **Regulatory Quality: Estimate** (`object`): A measure of the government's ability to create and enforce regulations.
# 29. **Rule of Law: Estimate** (`object`): A measure of confidence in and adherence to laws.
# 30. **Voice and Accountability: Estimate** (`object`): A measure of citizens' ability to participate in governance.
#
# ### **Technology**
# 31. **Individuals using the Internet (% of population)** (`object`): The percentage of individuals using the Internet.
# 32. **Research and development expenditure (% of GDP)** (`object`): The percentage of GDP spent on research and development.
# 33. **High-technology exports (% of manufactured exports)** (`object`): The percentage of manufactured exports that are high-technology products.
#
# ---
#
# ### **Summary**
# - The dataset includes a mix of **numeric** and **categorical** columns.
# - **Numeric columns** (e.g., GDP, population) are stored in types like `float64` or `int64`, while many **categorical columns** (e.g., corruption perception) are stored as `object`.
# - It covers diverse indicators across economics, labor, demographics, health, governance, and environment.
