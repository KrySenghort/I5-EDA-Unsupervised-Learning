# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1.  Load Data

# %%
df = pd.read_csv('South_Asian_dataset.csv')

# %%
df.head()
# Out:
#        Country  Year  GDP (current US$)  GDP growth (annual %)  \
# 0  Afghanistan  2000       3.521418e+09                    NaN
# 1  Afghanistan  2001       2.813572e+09              -9.431974
# 2  Afghanistan  2002       3.825701e+09              28.600001
# 3  Afghanistan  2003       4.520947e+09               8.832278
# 4  Afghanistan  2004       5.224897e+09               1.414118
#
#    GDP per capita (current US$)  \
# 0                    180.188369
# 1                    142.903364
# 2                    182.174038
# 3                    199.643226
# 4                    221.830531
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                              7.955
# 1                                              7.958
# 2                                              7.939
# 3                                              7.922
# 4                                              7.914
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 33 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Country                                                                     192 non-null    object
#  1   Year                                                                        192 non-null    int64
#  2   GDP (current US$)                                                           190 non-null    float64
#  3   GDP growth (annual %)                                                       189 non-null    float64
#  4   GDP per capita (current US$)                                                190 non-null    float64
#  5   Unemployment, total (% of total labor force) (modeled ILO estimate)         192 non-null    float64
# ...

# %%
df.describe()
# Out:
#               Year  GDP (current US$)  GDP growth (annual %)  \
# count   192.000000       1.900000e+02             189.000000
# mean   2011.500000       2.910099e+11               5.065082
# std       6.940284       6.701374e+11               6.265406
# min    2000.000000       4.607334e+08             -32.908829
# 25%    2005.750000       5.291861e+09               3.525153
# 50%    2011.500000       3.066091e+10               5.456388
# 75%    2017.250000       1.931948e+11               7.123428
# max    2023.000000       3.549920e+12              37.687192
#
#        GDP per capita (current US$)  \
# count                    190.000000
# mean                    2161.422299
# std                     2465.328490
# min                      142.903364
# 25%                      632.294526
# 50%                     1250.093340
# 75%                     2689.319415
# max                    12667.435670
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# ...

# %% [markdown]
# * Check for each column's unique

# %%
for col in df.columns:
    print(col, ':')
    print(df[col].value_counts(), '\n')
# Out:
# Country :
# Afghanistan    24
# Bhutan         24
# Bangladesh     24
# India          24
# Maldives       24
# Sri Lanka      24
# Nepal          24
# Pakistan       24
# Name: Country, dtype: int64
#
# Year :
# 2000    8
# 2001    8
# 2022    8
# 2021    8
# 2020    8
# 2019    8
# 2018    8
# 2017    8
# 2016    8
# 2015    8
# 2014    8
# 2013    8
# 2012    8
# 2011    8
# 2010    8
# 2009    8
# 2008    8
# 2007    8
# 2006    8
# 2005    8
# 2004    8
# 2003    8
# 2002    8
# 2023    8
# Name: Year, dtype: int64
#
# GDP (current US$) :
# 3.521418e+09    1
# 7.044722e+10    1
# 1.888177e+10    1
# 2.066253e+10    1
# 2.440579e+10    1
#                ..
# 3.512320e+11    1
# 3.739790e+11    1
# 4.162720e+11    1
# 4.601320e+11    1
# 3.383680e+11    1
# Name: GDP (current US$), Length: 190, dtype: int64
#
# GDP growth (annual %) :
# -9.431974    1
#  4.051746    1
#  5.445061    1
#  6.241748    1
#  7.668292    1
#             ..
#  3.448018    1
#  6.938679    1
# ...

# %% [markdown]
# ### 2. Data Cleaning

# %% [markdown]
# **Droping Feature:**

# %% [markdown]
# ### What and how Feature that we want to drop

# %%
df = df.drop(df[df['Name'].str.contains('.....')].index)
df['Name'].unique()

# %%
df.shape
# Out:
# (192, 33)

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values
missing_value = df.isnull().sum()
missing_value
# Out:
# Country                                                                         0
# Year                                                                            0
# GDP (current US$)                                                               2
# GDP growth (annual %)                                                           3
# GDP per capita (current US$)                                                    2
# Unemployment, total (% of total labor force) (modeled ILO estimate)             0
# Inflation, consumer prices (annual %)                                           9
# Foreign direct investment, net inflows (% of GDP)                               5
# Trade (% of GDP)                                                               51
# Gini index                                                                    150
# Population, total                                                               0
# ...

# %%
# Check for total missing values
total_missing = df.isnull().sum().sum()
print(f"\nTotal missing values: {total_missing}")
# Out:
# Total missing values: 222

# %%
# Show rows with missing values
rows_with_missing = df[df.isnull().any(axis=1)]
print("\nRows with missing values:")
print(rows_with_missing)
# Out:
# Rows with missing values:
#          Country  Year  GDP (current US$)  GDP growth (annual %)  \
# 0    Afghanistan  2000       3.521418e+09                    NaN
# 1    Afghanistan  2001       2.813572e+09              -9.431974
# 2    Afghanistan  2002       3.825701e+09              28.600001
# 3    Afghanistan  2003       4.520947e+09               8.832278
# 4    Afghanistan  2004       5.224897e+09               1.414118
# ..           ...   ...                ...                    ...
# 187     Pakistan  2019       3.209090e+11               2.497637
# 188     Pakistan  2020       3.004260e+11              -1.274087
# 189     Pakistan  2021       3.485170e+11               6.513886
# 190     Pakistan  2022       3.747880e+11               4.767540
# 191     Pakistan  2023       3.383680e+11              -0.004855
#
#      GDP per capita (current US$)  \
# 0                      180.188369
# 1                      142.903364
# 2                      182.174038
# ...

# %% [markdown]
# <hr>
# - There is have missing value in this dataset:
#
# - GDP (current US$)     2
#
# - GDP growth (annual %) 3
#
# - GDP per capita (current US$)  2
#
# - Inflation, consumer prices (annual %)  9
#
# - Foreign direct investment, net inflows (% of GDP)     5
#
# - Trade (% of GDP) 51
#
# - Gini index   150
# <hr>

# %% [markdown]
# ### Duplicated Value

# %%
duplicated_row = df[df.duplicated()]
if len(duplicated_row) > 0:
    print('The following rows are duplicated: ')
    print(duplicated_row)
else:
    print('No duplicated rows found.')
# Out:
# No duplicated rows found.

# %% [markdown]
# <hr>
# There is no duplicated value in this dataset.
# <hr>

# %% [markdown]
# ### Outlier

# %%
# Create box plots for each numerical column to visualize outliers
for col in numeric_columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=df[col])
    plt.title(f'Outlier for {col}')
    plt.show()

# %% [markdown]
# ### Encoding categorical variables

# %%
df.describe(include = 'object')
# Out:
#             Country  \
# count           192
# unique            8
# top     Afghanistan
# freq             24
#
#        Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# count                                                 192
# unique                                                 39
# top                                                    ..
# freq                                                  150
#
#        Life expectancy at birth, total (years)  \
# count                                      192
# unique                                     185
# top                                         ..
# freq                                         8
#
#        Mortality rate, infant (per 1,000 live births)  \
# count                                             192
# unique                                            173
# top                                                ..
# freq                                                8
#
# ...

# %%
categorical_cols = df.select_dtypes(include = 'O')
categorical_cols.head(5)
# Out:
#        Country  \
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan
#
#   Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Life expectancy at birth, total (years)  \
# 0                                  55.298
# 1                                  55.798
# 2                                  56.454
# 3                                  57.344
# 4                                  57.944
#
#   Mortality rate, infant (per 1,000 live births)  \
# 0                                             92
# 1                                           89.3
# 2                                           86.6
# 3                                           83.7
# ...

# %%
categoric_col = []
numeric_col = []
for col in df.columns:
    if df[col].dtype == 'object':
        categoric_col.append(col)
    else:
        numeric_col.append(col)
print('Categorical variable: ', categoric_col) 
print('Numrical variable: ', numeric_col)
# Out:
# Categorical variable:  ['Country', 'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)', 'Life expectancy at birth, total (years)', 'Mortality rate, infant (per 1,000 live births)', 'Literacy rate, adult total (% of people ages 15 and above)', 'School enrollment, primary (% gross)', 'Access to electricity (% of population)', 'People using at least basic drinking water services (% of population)', 'People using at least basic sanitation services (% of population)', 'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)', 'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)', 'Renewable energy consumption (% of total final energy consumption)', 'Forest area (% of land area)', 'Control of Corruption: Percentile Rank', 'Political Stability and Absence of Violence/Terrorism: Estimate', 'Regulatory Quality: Estimate', 'Rule of Law: Estimate', 'Voice and Accountability: Estimate', 'Individuals using the Internet (% of population)', 'R
# ...

# %%
df.head(4)
# Out:
#        Country  Year  GDP (current US$)  GDP growth (annual %)  \
# 0  Afghanistan  2000       3.521418e+09                    NaN
# 1  Afghanistan  2001       2.813572e+09              -9.431974
# 2  Afghanistan  2002       3.825701e+09              28.600001
# 3  Afghanistan  2003       4.520947e+09               8.832278
#
#    GDP per capita (current US$)  \
# 0                    180.188369
# 1                    142.903364
# 2                    182.174038
# 3                    199.643226
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                              7.955
# 1                                              7.958
# 2                                              7.939
# 3                                              7.922
#
#    Inflation, consumer prices (annual %)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# ...

# %% [markdown]
# ### 3. Data Exploration

# %% [markdown]
# * Count all values in categorical feature

# %%
# Calculate the correlation matrix
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'GDP (current US$)', 'GDP growth (annual %)',
#        'GDP per capita (current US$)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        'Inflation, consumer prices (annual %)',
#        'Foreign direct investment, net inflows (% of GDP)', 'Trade (% of GDP)',
#        'Gini index', 'Population, total', 'Population growth (annual %)',
#        'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)',
#        'Life expectancy at birth, total (years)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'Literacy rate, adult total (% of people ages 15 and above)',
#        'School enrollment, primary (% gross)',
#        'Urban population (% of total population)',
#        'Access to electricity (% of population)',
#        'People using at least basic drinking water services (% of population)',
#        'People using at least basic sanitation services (% of population)',
# ...

# %% [markdown]
# ### 4. Data Visualization

# %%
sns.pairplot(df, kind = 'scatter')
